# %%
import yfinance as yf
from curl_cffi.cli.output import determine_print_spec

# Example: Apple stock
data = yf.download("AAPL", start="2020-01-01", end="2023-01-01")
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.400520  72.460784  71.156682  71.409785  135480400
# 2020-01-03  71.696617  72.455935  71.472439  71.629122  146322800
# 2020-01-06  72.267937  72.306506  70.568510  70.819208  118387200
# 2020-01-07  71.928062  72.533103  71.708703  72.277586  108872000
# 2020-01-08  73.085114  73.386431  71.631559  71.631559  132079200

# %%
X = data[['Open', 'High', 'Low', 'Volume']]
y = data['Close']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(y_test.values, label="Actual")
plt.plot(predictions, label="Predicted")
plt.legend()
plt.title("Stock Price Prediction")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mean_squared_error(y_test, predictions))

print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 0.7572127520659364
# Root Mean Squared Error: 0.9658203163445872
